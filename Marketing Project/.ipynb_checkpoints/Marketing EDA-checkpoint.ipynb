# %%
import pandas as pd

# %%
bus=pd.read_csv('businessfiltered.csv')
checkin=pd.read_csv('checkinfiltered.csv')
review=pd.read_csv('reviewsandsent.csv')
tip=pd.read_csv('tipfiltered.csv')
user=pd.read_csv('userfiltered.csv')

# %% [markdown]
# ### Alter data sets to give only what I need to focus on

# %%
review_bus = review[['text', 'business_id','stars']]
attribute_list = []
for i in bus.columns:
    if i[:5] == 'attri':
        fill, attr = i.split('.',1)
        attribute_list.append(attr)

# %%
s=set([])
attr_list = []
a =[]
for i in attribute_list:
    a = i.lower().split('.')
    for b in a:
        s.add(b)
        attr_list.append(b)

# %%
attribute_set = set({'acceptsinsurance', 'african american', 'agesallowed', 'alcohol', 'ambience', 'asian', 'background music', 'bestnights', 'bikeparking', 'breakfast',
 'brunch', 'businessacceptsbitcoin',  'businessacceptscreditcards', 'businessparking', 'byappointmentonly', 'byob', 'byobcorkage',
 'casual', 'caters', 'classy', 'coatcheck', 'coloring', 'corkage', 'curly', 'dairy-free', 'dessert', 'dietaryrestrictions',
 'dinner', 'divey', 'dj', 'dogsallowed', 'drivethru', 'extensions', 'friday', 'garage', 'gluten-free', 'goodfordancing',
 'goodforkids', 'goodformeal', 'hairspecializesin', 'halal', 'happyhour', 'hastv',
 'hipster', 'intimate', 'jukebox', 'karaoke', 'kids', 'kosher', 'latenight', 'live',
 'lot', 'lunch', 'music', 'no_music', 'noiselevel', 'open24hours', 'outdoorseating',
 'perms', 'attire', 'counterservice', 'delivery', 'groups', 'reservations', 'table service', 'takeout',
 'romantic',  'smoking', 'soy-free', 'perms', 'street', 'touristy', 'trendy', 'upscale',
 'valet', 'validated', 'vegan', 'vegetarian', 'video', 'wheelchair', 'wifi'})

# %%
import pandas as pd
from pandas import Series, DataFrame
import pandas as pd
import numpy as np  
import re
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
import itertools
# %pylab inline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yanni\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Populating the interactive namespace from numpy and matplotlib

# %%
def message_to_attributes(message):
    # Function to convert a raw message to a string of words
    #
    # 1. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", str(message)) 
    #
    # 2. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #                
    # 4. Remove stop words
    meaningful_words = [w for w in words if  w in attribute_set]    
    #
    # 5. Remove duplicates
    uwords = []
    [uwords.append(x) for x in meaningful_words if x not in uwords]
    # 6. Join the words back into one string separated by space, 
    onestring = ( " ".join( uwords )) 
    #
    total_messages.append(onestring)
    # 7. return the string
    return onestring

# %%
total_messages = []
review_bus['attributes'] = review_bus['text'].map(message_to_attributes)
# Out:
# C:\Users\yanni\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def get_bus_attr(message):
    attribute_per_listing = []
    for label in message.axes:
        str_list = str(message[label]).split('\n')
        for item in str_list:
            if item[:3] == 'att':
                item = " ".join(item.split())
                attribute, result = item.split(' ')
                attribute = attribute.split('.')[1]
                if len(result) == 4:
                    attribute=attribute.lower()
                    attribute_per_listing.append(attribute)
    return attribute_per_listing

# %%
bus['attributes_list'] = bus.apply(get_bus_attr, 1)

# %%
bus_attr = bus[['attributes_list', 'business_id']]

# %%
bus_attr.set_index(bus_attr['business_id'])
review_bus.set_index(review_bus['business_id'])
# Out:
#                                                                      text  \
# business_id
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    4.0
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    4.0
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    5.0
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    4.0               music
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    4.0               music
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    3.0
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    3.0
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    2.0
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    3.0
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    4.0
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    4.0              friday
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    5.0
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    3.0              trendy
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    5.0
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    5.0               music
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    5.0   vegetarian caters
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    4.0              street
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    5.0
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    2.0              trendy
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    4.0       dinner street
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    4.0
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    5.0            live lot
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    1.0                 lot
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    4.0            intimate
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    5.0                 lot
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    3.0             hipster
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    5.0             dessert
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    2.0
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    5.0  music lunch street
# iJ4uoZkPNJ39Vfh0HirI3w  iJ4uoZkPNJ39Vfh0HirI3w    5.0              street
#
# [1456266 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
vectorizer = CountVectorizer(analyzer = "word",   
                             tokenizer = None,    
                             preprocessor = None, 
                             stop_words = None,   
                             max_features = 5000) 

brandwords = vectorizer.fit_transform(total_messages)
brandvocab = vectorizer.get_feature_names()
df_brandcounts = pd.DataFrame(data = brandwords.toarray() , columns = brandvocab).T
df_brandcounts.head()
# Out:
#            0        1        2        3        4        5        6        \
# alcohol          0        0        0        0        0        0        0
# ambience         0        0        0        0        0        0        0
# asian            0        0        0        0        0        0        0
# attire           0        0        0        0        0        0        0
# breakfast        0        0        0        0        0        0        0
#
#            7        8        9         ...     1456256  1456257  1456258  \
# alcohol          0        0        0   ...           0        0        0
# ambience         0        0        0   ...           0        0        0
# asian            0        0        0   ...           0        0        0
# attire           0        0        0   ...           0        0        0
# breakfast        0        0        0   ...           0        0        0
#
#            1456259  1456260  1456261  1456262  1456263  1456264  1456265
# alcohol          0        0        0        0        0        0        0
# ambience         0        0        0        0        0        0        0
# asian            0        0        0        0        0        0        0
# attire           0        0        0        0        0        0        0
# breakfast        0        0        0        0        0        0        0
#
# [5 rows x 1456266 columns]

# %%
df_brandcounts['Total Counts'] = df_brandcounts.sum(axis=1)
lenght_list=[]

# %%
from sklearn import metrics
dummy = ones(53)
cossim = cosine_similarity(X=brandwords, Y=dummy)
my_list = map(lambda x: x[0], cossim)
ser = pd.Series(my_list)
review_bus['Cosine Similarity'] = ser
# Out:
# C:\Users\yanni\Anaconda2\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\yanni\Anaconda2\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
mean(review_bus['Cosine Similarity'])
# Out:
# 0.06003045119070513

# %%
review_bus.sort_values(['Cosine Similarity'], ascending=False)
# Out:
#                                                       text  \
# 945600   In the two years that I've lived in the Vegas ...
# 704434   I spent this past weekend at Paris for my best...
# 783179   Our initial thoughts of getting married in Veg...
# 704028   I received an Identity Membership promotion vi...
# 1012055  Warning: LONG REVIEW. SORRY =)\r\n\r\nI was su...
# 924535   Summary: Go here if you're an iced tea snob, m...
# 35105    Excerpted from a longer blog post about my exp...
# 1360592  We come to Las Vegas for business and pleasure...
# 142348   Rating for: LUNCH\r\n\r\nI'm giving this buffe...
# 704684   I was in town for a yearly conference; the gir...
# 39278    Stay at The Cosmopolitan and you're going to h...
# 769223   I see I'm going to have to rescue this place f...
# 652071   5 Stars for T-bird Lounge\r\n T-bird Lounge is...
# 1392085  Crush is a fantastic dinner spot, located in t...
# 71307    Wow!  What a disappointment this 'romantic' di...
# 345865   The old fashioned charm of a classic Tiki bar ...
# 599184   Ok, I read all of your blogs and comments befo...
# 1234961  Nice place for large group meetups.  As we did...
# 1368393  I have heard the words "Best buffet in Las Veg...
# 540553   This is a great place to be in Vegas, but not ...
# 1187139  This is not a 5-star hotel by any stretch of t...
# 38517    The Cosmopolitan is by far my favorite hotel i...
# 764845   I have been anxiously waiting to try Giada eve...
# 765874   This was our place of choice for a Saturday ev...
# 350664   This buffet is outstanding.  It's one of the b...
# 620145   I cannot wait to go back to DW Bistro. It is s...
# 1088895  I live in SE Las Vegas.  My sister and I gave ...
# 518287   Funkler and Snowball.... Great desserts!\r\n\r...
# 1154735  I've dined at 'fine dining' establishments bef...
# 716592   This review is for Sunday's Jazz Brunch. I'm a...
# ...                                                    ...
# 793903   Sat right next to Gordon Ramsay's table.Our fo...
# 793902   It's more of a novelty coming here especially ...
# 793901   Poor experience and questionable ethics from t...
# 793900   A bit more pricey for regular American food bu...
# 286929   Although the dining area is small, it is well ...
# 793875   I had been dying to try the frozen hot chocola...
# 793876   Serendipity?\r\n\r\nI seriously had high hopes...
# 286928   I really appreciate a place that has a small m...
# 286927   Went here a few days ago during a weekday - it...
# 793879   So, my friends and I decided to make our way t...
# 793880   great place to sit and people watch while you ...
# 793881   Went here last week and had the meatball pizza...
# 793882   On my recent trip to Vegas I was so excited to...
# 286926   This is my favorite place to eat, with a cheap...
# 793884   The worst experience ever !! We were there 3 d...
# 793885   Food is good, but there is nothing amazing abo...
# 286924   Super rich broth, very similar to ramen in J-t...
# 793888   We stopped by here for a late-night treat last...
# 793889                                       closes early.
# 286923   Delicious and flavorful ramen. It's very fast ...
# 793891   Easily one of the best places I've ever eaten ...
# 793892   Hot chocolate was awesome! The food was good w...
# 286922   I had a very bizarre experience here. When I a...
# 793894   I wanted my first time to be in NYC, but I sti...
# 793895   I was really looking forward to coming here fo...
# 286921   I am from south of Japan where Tonkotsu ramen ...
# 286920   This is my first review so be gentle! I would ...
# 286919   This place changed my idea of Ramen noodles. O...
# 793899   The portion sizes are enormous and that's prob...
# 0        A beautiful set of high end shops. I can't rea...
#
#                     business_id  stars  \
# 945600   k8BqCejnaMlw7aoVthvqyw    4.0
# 704434   ii8sAGBexBOJoYRFafF9XQ    4.0
# 783179   TSGQekzPDF9dCj3bNsehJw    5.0
# 704028   1DP5vHxJzCDbgawv0WC3yA    5.0
# 1012055  bpRo8L8dkhgbJhdIKa9mwA    4.0
# 924535   VzUo-RURV3VnfNItAYM8yg    5.0
# 35105    5LNZ67Yw9RD6nf4_UhXOjw    5.0
# 1360592  eEnNw3_hBvxcFHyr23kAuA    5.0
# 142348   2weQS-RnoOBhb1KsHKyoSQ    5.0
# 704684   AMTNJbYbu0OMMAkx4meQxw    5.0
# 39278    5LNZ67Yw9RD6nf4_UhXOjw    5.0
# 769223   kmdFk8ETfXiuoS364jaJFA    4.0
# 652071   tlZmJBQ9UWkaI0Zce_KFhg    5.0
# 1392085  gc_GGat7TgNCmrgc4nVOgw    4.0
# 71307    uuGlYAIvYAX1q1KhpY6dtA    1.0
# 345865   _3olhuCXhoqjy4M2rBp1YA    5.0
# 599184   q3dJQtwZQrrurNT-1bNKgQ    4.0
# 1234961  VsewHMsfj1Mgsl2i_hio7w    4.0
# 1368393  RESDUcs7fIiihp38-d6_6g    5.0
# 540553   mbLguBsFuy34zKlor2xcIg    4.0
# 1187139  6Ct57qgmXwOnzfSZoUGh0Q    3.0
# 38517    5LNZ67Yw9RD6nf4_UhXOjw    5.0
# 764845   G-5kEa6E6PD5fkBRuA7k9Q    3.0
# 765874   IRbgMt0cVuzK1KSppU16_Q    5.0
# 350664   ujHiaprwCQ5ewziu0Vi9rw    4.0
# 620145   qqs7LP4TXAoOrSlaKRfz3A    5.0
# 1088895  XiN6fI8I3Mzg2nPRJ9ukRQ    5.0
# 518287   biSsdqExmdvIKiFuowOadg    3.0
# 1154735  ahSFUPojs9X3-1jP-QPb-w    2.0
# 716592   41b2SLmjLcxTGLVRxASiDA    4.0
# ...                         ...    ...
# 793903   eoHdUeQDNgQ6WYEnP2aiRw    5.0
# 793902   eoHdUeQDNgQ6WYEnP2aiRw    2.0
# 793901   eoHdUeQDNgQ6WYEnP2aiRw    1.0
# 793900   eoHdUeQDNgQ6WYEnP2aiRw    3.0
# 286929   UPIYuRaZvknINOd1w8kqRQ    5.0
# 793875   eoHdUeQDNgQ6WYEnP2aiRw    4.0
# 793876   eoHdUeQDNgQ6WYEnP2aiRw    2.0
# 286928   UPIYuRaZvknINOd1w8kqRQ    4.0
# 286927   UPIYuRaZvknINOd1w8kqRQ    4.0
# 793879   eoHdUeQDNgQ6WYEnP2aiRw    3.0
# 793880   eoHdUeQDNgQ6WYEnP2aiRw    4.0
# 793881   eoHdUeQDNgQ6WYEnP2aiRw    3.0
# 793882   eoHdUeQDNgQ6WYEnP2aiRw    1.0
# 286926   UPIYuRaZvknINOd1w8kqRQ    5.0
# 793884   eoHdUeQDNgQ6WYEnP2aiRw    1.0
# 793885   eoHdUeQDNgQ6WYEnP2aiRw    3.0
# 286924   UPIYuRaZvknINOd1w8kqRQ    4.0
# 793888   eoHdUeQDNgQ6WYEnP2aiRw    4.0
# 793889   eoHdUeQDNgQ6WYEnP2aiRw    2.0
# 286923   UPIYuRaZvknINOd1w8kqRQ    4.0
# 793891   eoHdUeQDNgQ6WYEnP2aiRw    5.0
# 793892   eoHdUeQDNgQ6WYEnP2aiRw    4.0
# 286922   UPIYuRaZvknINOd1w8kqRQ    2.0
# 793894   eoHdUeQDNgQ6WYEnP2aiRw    4.0
# 793895   eoHdUeQDNgQ6WYEnP2aiRw    5.0
# 286921   UPIYuRaZvknINOd1w8kqRQ    5.0
# 286920   UPIYuRaZvknINOd1w8kqRQ    4.0
# 286919   UPIYuRaZvknINOd1w8kqRQ    5.0
# 793899   eoHdUeQDNgQ6WYEnP2aiRw    2.0
# 0        RLFIsHWmOFm-WsGfOTmH5Q    3.0
#
#                                                 attributes  Cosine Similarity
# 945600   live music dinner lot ambience attire groups c...           0.495261
# 704434   dinner ambience live music alcohol breakfast l...           0.434372
# 783179   live music delivery dinner brunch upscale vege...           0.434372
# 704028   lot classy dj dinner music intimate reservatio...           0.434372
# 1012055  lot groups romantic music live dj alcohol dess...           0.434372
# 924535   dinner music groups lot breakfast lunch kids w...           0.412082
# 35105    dinner street live reservations romantic brunc...           0.412082
# 1360592  friday music valet live dessert delivery lot r...           0.412082
# 142348   lunch dessert ambience casual dinner halal kos...           0.412082
# 704684   reservations dinner ambience romantic lot dess...           0.412082
# 39278    classy dessert music upscale video alcohol str...           0.412082
# 769223   live breakfast lunch dinner friday brunch asia...           0.412082
# 652071   dinner kids lunch breakfast groups lot dj vide...           0.412082
# 1392085  dinner ambience intimate trendy romantic desse...           0.412082
# 71307    romantic dinner reservations ambience music al...           0.412082
# 345865   asian intimate casual video dj live music alco...           0.412082
# 599184   valet classy live dinner music romantic alcoho...           0.412082
# 1234961  brunch groups breakfast lunch dinner casual at...           0.412082
# 1368393  dinner lunch lot breakfast friday brunch asian...           0.412082
# 540553   garage lot casual valet breakfast lunch dinner...           0.412082
# 1187139  valet groups video music dessert lot dj street...           0.412082
# 38517    trendy classy lot music casual lunch intimate ...           0.412082
# 764845   lunch dinner valet intimate music video classy...           0.412082
# 765874   dinner upscale vegan alcohol casual ambience m...           0.412082
# 350664   reservations breakfast lunch brunch dessert al...           0.412082
# 620145   hipster trendy casual intimate dessert dinner ...           0.412082
# 1088895  live lunch ambience attire casual classy roman...           0.388514
# 518287   asian upscale groups vegetarian friday dessert...           0.388514
# 1154735  dinner classy upscale attire casual reservatio...           0.388514
# 716592   brunch vegan dinner live music breakfast kids ...           0.388514
# ...                                                    ...                ...
# 793903                                                               0.000000
# 793902                                                               0.000000
# 793901                                                               0.000000
# 793900                                                               0.000000
# 286929                                                               0.000000
# 793875                                                               0.000000
# 793876                                                               0.000000
# 286928                                                               0.000000
# 286927                                                               0.000000
# 793879                                                               0.000000
# 793880                                                               0.000000
# 793881                                                               0.000000
# 793882                                                               0.000000
# 286926                                                               0.000000
# 793884                                                               0.000000
# 793885                                                               0.000000
# 286924                                                               0.000000
# 793888                                                               0.000000
# 793889                                                               0.000000
# 286923                                                               0.000000
# 793891                                                               0.000000
# 793892                                                               0.000000
# 286922                                                               0.000000
# 793894                                                               0.000000
# 793895                                                               0.000000
# 286921                                                               0.000000
# 286920                                                               0.000000
# 286919                                                               0.000000
# 793899                                                               0.000000
# 0                                                                    0.000000
#
# [1456266 rows x 5 columns]

# %%
review_bus.groupby(['business_id'])['Cosine Similarity'].mean().sort_values(ascending = False)
# Out:
# business_id
# jWUShkhq7Fe3OKr3NvQecQ    0.225442
# v9nBMrPJDLrEkwX02Txf3Q    0.221078
# hCSNmhsjMyLnpGasEcOENw    0.208810
# qFxuhYK5VzuZ8BbNNHGK-A    0.208810
# mKC0qzGy50IFb5Rp86Nv6w    0.208810
# --DdmeR16TRb3LsjG0ejrQ    0.205055
# 3WwyJXS5i0K9pjTDpxu65A    0.204397
# uRyGleoLHgMVp7StcJfj7g    0.201360
# 7eJGceqlI4c9Yd2uXulBug    0.200149
# Q3sbnOLbr7g-5Kehtvxs0A    0.198790
# 78SftdHMXEHdQVs24z39fw    0.196712
# GYTE331LlKZr6O0ADFDSdA    0.194257
# LAoK-5hDjqALXQ9F6RrVIw    0.194257
# 4ZhvG-t28ZoViCFXiANwSw    0.194257
# RxcEcmNx4XiQWb8oRdFEYQ    0.194077
# WVsRzlRdnK4rKKWdeLYR1w    0.192686
# aNFgmPNMXI-qjDB_d45oWQ    0.192051
# WfITErw6wT8HrzQdMeLjsg    0.190948
# 7SBtCKKeHbdB6-dIIkcZXw    0.190697
# SYIVQISajxm2J9lAnMp1RA    0.189844
# 1f9jrB7LDPZGS2AXW0o67A    0.189844
# bIizBQc3QrGz3i59EiOivw    0.189844
# Ig-ecmGaE1-0AAGut70xTg    0.189844
# DsMIfKq8pZgcgcrryHDKRA    0.189844
# K5MVCy1gPnExQPEKnCnh8A    0.188186
# LlJ5O6zbSxK9U2fsJeScXg    0.187638
# QpHJvtmTWWoiz42bb2nTiA    0.187638
# bXISj8RpXaAilaPLtJuzKg    0.187638
# KWBCsxyH7OxsibiY95fx2g    0.185785
# qJFyEn2PE20zIA1-BoAeXA    0.184238
#                             ...
# aCEWrGt7_Ke3Mn6s1qpd9A    0.000000
# aBieCdx2YLCLm0x3isIdPw    0.000000
# aBen6ybUULH4o-h1vwKWgg    0.000000
# a9aCSNIF176GHYEAb5jSqg    0.000000
# a9HohAzIxFHHMsA5S7KZBg    0.000000
# ApXcBer3f78tA6IRQDM9xg    0.000000
# AqTshi0CuSavA1BFFQ3Mkw    0.000000
# aJI-KCv_mYAlz5WqydBe6Q    0.000000
# aKymOxfEj1zSumS9wi8zjQ    0.000000
# aU0xh_ALzSb8MrYyYvQ0xQ    0.000000
# aQsbyexTfc93brgqywBcpg    0.000000
# Ae_sIzswj8b6bNVssTQbsg    0.000000
# aU-Ji_Oe9dFN336x39FOew    0.000000
# aTBvs6tERUfPV2az7JRb-Q    0.000000
# aT9vsiHEu1p0gsIHNVr3_A    0.000000
# aSgkAssOTsC20SeKEFiung    0.000000
# aRyXbE14N7-XGKBtVmVGCw    0.000000
# aRV-V3RXVk9c5YPSNyNjzA    0.000000
# AgUbPJWyp3VDWgt-gaswrg    0.000000
# aQQ457hZMeYUxdDvyTZrHw    0.000000
# AkED0tHIbZfe1rYEp-HWgw    0.000000
# AhQ4CSFw-agZMGfm1HwosA    0.000000
# aQOYZARifMo_tfQipVsRrA    0.000000
# aQNElmtSzlxFEw2IzSFkgA    0.000000
# aQ1u1yHpK_y8kjSiq_wmsQ    0.000000
# aO3IR4oyToqeYIdvz1p42A    0.000000
# Aiyyisbbf8WgH_pfl1VQfQ    0.000000
# aMOCpkCjjjD5InYwIIkAoQ    0.000000
# aLQYWeR6MNMDSrNW54j-Uw    0.000000
# V4o2zjZXnsEIT-bPkEXneQ    0.000000
# Name: Cosine Similarity, Length: 24769, dtype: float64

# %%
review_bus.groupby(['stars'])['Cosine Similarity'].mean().sort_values(ascending = False)
# Out:
# stars
# 4.0    0.075704
# 3.0    0.075088
# 2.0    0.065206
# 5.0    0.051521
# 1.0    0.045030
# Name: Cosine Similarity, dtype: float64

# %%
review_bus['Cosine Similarity'].hist(bins=50)
